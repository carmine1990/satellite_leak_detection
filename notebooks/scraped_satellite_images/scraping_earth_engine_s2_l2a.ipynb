# %% [markdown]
# ## Dati Satellite Sentinel-2 L2A Processing (multispectral bands)

# %%
from path import Path
import arrow
import json
import pytz
from pprint import pprint
from tqdm.notebook import tqdm
import re, os, collections, itertools, uuid, logging
import tempfile
import shapely

import zipfile
import urllib

import ee
import pyproj
import numpy as np
import scipy as sp
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (15, 5) # bigger plots
plt.style.use('fivethirtyeight')
# %matplotlib inline
# %precision 4
# Out:
# '%.4f'

# %%
helper_dir = str(Path('..').abspath())
if helper_dir not in os.sys.path:
    os.sys.path.append(helper_dir)
    
from leak_helpers.earth_engine import display_ee, get_boundary, tifs2np, bands_s2_l2a, bands_s2_l2a_dem, bands_srtm, download_image

# %%
# # Non voglio stampare i Warning
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # Load leaks
#
# Load the leaks from a geojson file and make sure they have unique fields reportdate and workorderid (see asserts below)

# %%
# load 
root = "../../../ricerca_perdite"
leaks = gpd.read_file(root+"/data/leak_dataset/leaks.geojson")

leaks_datas = [leaks]

leaks_datas
# Out:
# [         id  anno civico      comune  comune_loc  \
#  0         0  2015      0   PODENZANA   PODENZANA
#  1         1  2015      1     TRESANA     TRESANA
#  2         3  2015     00  pontremoli  PONTREMOLI
#  3         9  2016         pontremoli  PONTREMOLI
#  4        44  2021   None  PONTREMOLI  PONTREMOLI
#  ...     ...   ...    ...         ...         ...
#  1708  34754  2021     51    CAMAIORE    CAMAIORE
#  1709  34760  2021   None    CAMAIORE    CAMAIORE
#  1710  34873  2021   None   MASSAROSA   MASSAROSA
#  1711  34881  2021     24  FILATTIERA  FILATTIERA
#  1712  35025  2022   None   MASSAROSA   MASSAROSA
#
#                                              description  diametro  \
#  0       Perdita acqua dalla rete montedivalli podenzana     110.0
#  1     perdita su adduttrice serbatoio giovagallo ese...      90.0
#  2       rotture idriche addutrice serbatoio di s. marco     125.0
#  3                                      PERDITA STRADALE     110.0
#  4     Mancata fornitura idrica- PERDITA ACQUA DALLA ...      90.0
#  ...                                                 ...       ...
#  1708                    Perdita via quattro novembre 51      90.0
#  1709                           perdita acqua dalla rete      90.0
#  1710         Perdita di acqua vista da nostro personale     125.0
#  1711                                   PERDITA STRADALE      90.0
#  1712                           Perdita acqua dalla rete     100.0
#
#        l_intervento                       localita  location  ... objectid  \
#  0              0.0                      PODENZANA  38A05A01  ...        0
#  1              0.0                        TRESANA  45A07A04  ...        1
#  2              0.0                        BASSONE  39A01A18  ...        3
#  3              0.0                        DOZZANO  39A01A04  ...        9
#  4              0.0  LOCALITA' COSTA S. NICOLO' 23  39A01A08  ...       44
#  ...            ...                            ...       ...  ...      ...
#  1708           0.0                CAMAIORE CENTRO  07A01R05  ...    34754
#  1709           0.0                CAMAIORE CENTRO  07A01R05  ...    34760
#  1710           0.0             PIAN DEL QUERCIONE  28A01R08  ...    34873
#  1711           0.0                     FILATTIERA  18A01R01  ...    34881
#  1712           0.0                     BARGECCHIA  28A01R03  ...    35025
#
#                              reportdate serv_cost  status  \
#  0            2015-05-15T16:14:00+00:00    286.57   CLOSE
#  1            2015-05-30T17:14:00+00:00    220.99   CLOSE
#  2     2015-09-08T06:34:01.403000+00:00    645.88   CLOSE
#  3     2016-09-05T11:59:11.637000+00:00    539.55   CLOSE
#  4            2021-07-17T05:44:00+00:00   1057.92   CLOSE
#  ...                                ...       ...     ...
#  1708  2021-07-16T05:40:11.870000+00:00    411.85   CLOSE
#  1709         2021-07-19T04:50:00+00:00    607.40   CLOSE
#  1710  2021-09-04T15:13:31.657000+00:00    776.14   CLOSE
#  1711  2021-09-07T09:46:49.459999+00:00    653.46   CLOSE
#  1712         2022-01-30T11:30:00+00:00    725.97   CLOSE
#
#                                                  via        wonum workorderid  \
#  0                                          Genova 0  15ODL105517      434549
#  1                                        VIA BOLA 1  15ODL121318      449895
#  2                                           bassone  15ODL198239      526117
#  3                                           dozzano  16ODL315760      815762
#  4                     LOCALITA' COSTA S. NICOLO' 23  21ODL308113     2621776
#  ...                                             ...          ...         ...
#  1708                            quattro novembre 51  21ODL307918     2621532
#  1709                               VIA DI MEZZO 102  21ODL312931     2626643
#  1710                                     Montramito  21ODL359928     2674832
#  1711                               PONTE PROVINCILE  21ODL364825     2679778
#  1712  VIA DELLE SEZIONI 4480 Scala    Piano    Int.  22ODL138779     2834360
#
#                   x             y                   geometry
#  0     1.097467e+06  5.495690e+06   POINT (9.85871 44.19513)
#  1     1.099411e+06  5.502049e+06   POINT (9.87618 44.23608)
#  2     1.096196e+06  5.524731e+06   POINT (9.84730 44.38188)
#  3     1.098026e+06  5.522370e+06   POINT (9.86374 44.36673)
#  4     1.095851e+06  5.525300e+06   POINT (9.84420 44.38554)
#  ...            ...           ...                        ...
#  1708  1.147021e+06  5.455793e+06  POINT (10.30386 43.93762)
#  1709  1.146962e+06  5.457335e+06  POINT (10.30334 43.94759)
#  1710  1.146499e+06  5.447423e+06  POINT (10.29917 43.88345)
#  1711  1.105849e+06  5.516756e+06   POINT (9.93401 44.33066)
#  1712  1.146617e+06  5.449781e+06  POINT (10.30023 43.89871)
#
#  [1713 rows x 21 columns]]

# %%
# join them all, with primary columns and random metadata
primary_cols = ['workorderid','reportdate','geometry']
leaks = gpd.GeoDataFrame(pd.concat([leaks_data[primary_cols] for leaks_data in leaks_datas]), crs='epsg:4326')
leaks['metadata'] = np.concatenate([leaks_data.drop(primary_cols,1).to_dict('records') for leaks_data in leaks_datas])
leaks.index = leaks.workorderid
leaks
# Out:
# C:\Users\TRANFA~1.CAR\AppData\Local\Temp/ipykernel_17724/3025104378.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   leaks['metadata'] = np.concatenate([leaks_data.drop(primary_cols,1).to_dict('records') for leaks_data in leaks_datas])
#              workorderid                        reportdate  \
# workorderid
# 434549            434549         2015-05-15T16:14:00+00:00
# 449895            449895         2015-05-30T17:14:00+00:00
# 526117            526117  2015-09-08T06:34:01.403000+00:00
# 815762            815762  2016-09-05T11:59:11.637000+00:00
# 2621776          2621776         2021-07-17T05:44:00+00:00
# ...                  ...                               ...
# 2621532          2621532  2021-07-16T05:40:11.870000+00:00
# 2626643          2626643         2021-07-19T04:50:00+00:00
# 2674832          2674832  2021-09-04T15:13:31.657000+00:00
# 2679778          2679778  2021-09-07T09:46:49.459999+00:00
# 2834360          2834360         2022-01-30T11:30:00+00:00
#
#                               geometry  \
# workorderid
# 434549        POINT (9.85871 44.19513)
# 449895        POINT (9.87618 44.23608)
# 526117        POINT (9.84730 44.38188)
# 815762        POINT (9.86374 44.36673)
# 2621776       POINT (9.84420 44.38554)
# ...                                ...
# 2621532      POINT (10.30386 43.93762)
# 2626643      POINT (10.30334 43.94759)
# 2674832      POINT (10.29917 43.88345)
# 2679778       POINT (9.93401 44.33066)
# 2834360      POINT (10.30023 43.89871)
#
#                                                       metadata
# workorderid
# 434549       {'id': '0', 'anno': 2015, 'civico': '0', 'comu...
# 449895       {'id': '1', 'anno': 2015, 'civico': '1', 'comu...
# 526117       {'id': '3', 'anno': 2015, 'civico': '00', 'com...
# 815762       {'id': '9', 'anno': 2016, 'civico': '', 'comun...
# 2621776      {'id': '44', 'anno': 2021, 'civico': None, 'co...
# ...                                                        ...
# 2621532      {'id': '34754', 'anno': 2021, 'civico': '51', ...
# 2626643      {'id': '34760', 'anno': 2021, 'civico': None, ...
# 2674832      {'id': '34873', 'anno': 2021, 'civico': None, ...
# 2679778      {'id': '34881', 'anno': 2021, 'civico': '24', ...
# 2834360      {'id': '35025', 'anno': 2022, 'civico': None, ...
#
# [1713 rows x 4 columns]

# %%
# limit leaks to the time and space where satellite data exists
print('before',len(leaks))

# limit it to after satelite came into service
leaks= leaks[pd.to_datetime(leaks.reportdate)>pd.Timestamp('2017-03-28', tz='UTC')] 

# # also limit them by location
# satellite_bounds = shapely.geometry.box(
#     # continentental us
#     minx = -124.7844079, # west long
#     miny =  24.7433195, # south lat
#     maxx = -66.9513812, # east long
#     maxy = 49.3457868, # north lat   
# )
# leaks = leaks[leaks.intersects(satellite_bounds)]
print('after',len(leaks))
# Out:
# before 1713
# after 977

# %% [markdown]
# ## Params
#
# Customise the values in the cell below

# %%
# params
bands = bands_s2_l2a
satellite = 'COPERNICUS/S2_SR'
resolution_min = 10.0 # m
cloudy_percentage = 1

# since the lowest res band is 60m and I want to capture neighbours I should get 6+ pixels
pixel_length = 25.0

# you need to tweak this until you pass the "Test the distance need to get your rectangle" cell
fudge_distance_factor = -0.5

# %% [markdown]
# ## Init

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "notebook_name = " + "'"+thename+"'";
# kernel.execute(command);

# %%
#notebook_name='scraping_earth_engine_s2_l2a'
notebook_name
# Out:
# 'scraping_earth_engine_s2_l2a'

# %%
# constant params, probobly don't change
#time_bin_delta = 60*60*6 # how long before a leak to look (in seconds)
time_before_report = 5*24*60*60
time_after_report = 1*24*60*60
time_after_repair = 30*24*60*60
crs_grid = 3857 # keep this as auxilary sphere, this is the CRS the downloaded images will be in

# init
## init directories
ts=arrow.utcnow().format('YYYYMMDD-HH-mm-ss')
temp_dir = Path(root+'/data/scraped_satellite_images/'+satellite.replace("/","_")+'/tmp/')
output_dir = Path(root+'/data/scraped_satellite_images/'+satellite.replace("/","_"))
cache_dir = Path(output_dir+'/cache')
output_dir.makedirs_p()
temp_dir.makedirs_p()
cache_dir.makedirs_p()

## init logger
logger = logging.getLogger(notebook_name)
# logger.setLevel(logging.WARN)

temp_dir, output_dir, cache_dir
# Out:
# (Path('../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/tmp/'),
#  Path('../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR'),
#  Path('../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache'))

# %%
# # record cofig in a json file
# metadata = dict(
#     notebook_name=notebook_name,
#     satellite=satellite,
#     #time_bin_delta=time_bin_delta,
#     time_before=time_before,
#     time_after=time_after,
#     cloudy_percentage=cloudy_percentage,
#     pixel_length=pixel_length,
#     resolution_min=resolution_min,
#     bands=bands,
#     ts=ts,
#     crs_grid=crs_grid,
#     cache_dir=str(cache_dir),
#     temp_dir=str(temp_dir),
#     output_dir=str(output_dir),
# )
# metadata_file = output_dir.joinpath('script_metadata.json')
# json.dump(metadata, open(metadata_file,'w'))

# %% [markdown]
# # Earth Engine

# %%
# test earth-engine setup
from oauth2client import crypt # should have not error
import ee
ee.Initialize() # should give no errors, if so follow instructions

# test
image = ee.Image(ee.ImageCollection(satellite).first())
info = image.getInfo()
info
# Out:
# {'type': 'Image',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32635',
#    'crs_transform': [60, 0, 499980, 0, -60, 3000000]},
#   {'id': 'B2',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'B3',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'B4',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'B5',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'B6',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'B7',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'B8',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'B8A',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'B9',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32635',
#    'crs_transform': [60, 0, 499980, 0, -60, 3000000]},
#   {'id': 'B11',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'B12',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'AOT',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'WVP',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'SCL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'TCI_R',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'TCI_G',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'TCI_B',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'MSK_CLDPRB',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1, 1],
#    'crs': 'EPSG:32635',
#    'crs_transform': [1, 0, 499980, 0, 1, 3000000]},
#   {'id': 'MSK_SNWPRB',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 255},
#    'dimensions': [1, 1],
#    'crs': 'EPSG:32635',
#    'crs_transform': [1, 0, 499980, 0, 1, 3000000]},
#   {'id': 'QA10',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [10980, 10980],
#    'crs': 'EPSG:32635',
#    'crs_transform': [10, 0, 499980, 0, -10, 3000000]},
#   {'id': 'QA20',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 4294967295},
#    'dimensions': [5490, 5490],
#    'crs': 'EPSG:32635',
#    'crs_transform': [20, 0, 499980, 0, -20, 3000000]},
#   {'id': 'QA60',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
#     'max': 65535},
#    'dimensions': [1830, 1830],
#    'crs': 'EPSG:32635',
#    'crs_transform': [60, 0, 499980, 0, -60, 3000000]}],
#  'id': 'COPERNICUS/S2_SR/20170328T083601_20170328T084228_T35RNK',
#  'version': 1644772313475563,
#  'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20170328T083601_009213_N02.04',
#   'AOT_RETRIEVAL_ACCURACY': 0,
#   'CLOUD_COVERAGE_PERCENTAGE': 0.1250,
#   'SPACECRAFT_NAME': 'Sentinel-2A',
#   'FORMAT_CORRECTNESS_FLAG': 'PASSED',
#   'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 102.2983,
#   'CLOUD_SHADOW_PERCENTAGE': 0.0023,
#   'MEAN_SOLAR_AZIMUTH_ANGLE': 136.6837,
#   'system:footprint': {'type': 'LinearRing',
#    'coordinates': [[28.1074, 27.1182],
#     [28.1074, 27.1182],
#     [27.2123, 27.1224],
#     [27.2123, 27.1224],
#     [27.2122, 27.1224],
#     [27.2122, 27.1223],
#     [27.2116, 27.1213],
#     [27.2110, 27.1191],
#     [27.2049, 27.0947],
#     [27.0262, 26.3657],
#     [27.0039, 26.2741],
#     [26.9997, 26.2568],
#     [26.9997, 26.1313],
#     [26.9997, 26.1312],
#     [26.9998, 26.1312],
#     [28.0979, 26.1270],
#     [28.0979, 26.1270],
#     [28.0980, 26.1271],
#     [28.1027, 26.6226],
#     [28.1075, 27.1181],
#     [28.1075, 27.1181],
#     [28.1074, 27.1182]]},
#   'VEGETATION_PERCENTAGE': 0.8082,
#   'SOLAR_IRRADIANCE_B12': 85.2500,
#   'SOLAR_IRRADIANCE_B10': 367.1500,
#   'SOLAR_IRRADIANCE_B11': 245.5900,
#   'GENERATION_TIME': 1490833524000,
#   'SOLAR_IRRADIANCE_B8A': 955.1900,
#   'SENSOR_QUALITY_FLAG': 'PASSED',
#   'CLOUD_COVERAGE_ASSESSMENT': 0.9371,
#   'THIN_CIRRUS_PERCENTAGE': 0,
#   'system:time_end': 1490690548704,
#   'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#   'system:time_start': 1490690548704,
#   'DATASTRIP_ID': 'S2A_USER_MSI_L2A_DS_MPS__20170328T123128_S20170328T084228_N02.04',
#   'PROCESSING_BASELINE': '02.04',
#   'SENSING_ORBIT_NUMBER': 64,
#   'GEOMETRIC_QUALITY_FLAG': 'PASSED',
#   'NODATA_PIXEL_PERCENTAGE': 8.4290,
#   'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#   'GRANULE_ID': 'L2A_T35RNK_A009213_20170328T084228',
#   'LOW_PROBA_CLOUDS_PERCENTAGE': 3.2665,
#   'REFLECTANCE_CONVERSION_CORRECTION': 1.0061,
#   'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 0.1157,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 102.3832,
#   'DATATAKE_TYPE': 'INS-NOBS',
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 102.2555,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 102.3522,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 102.3184,
#   'RADIOMETRIC_QUALITY_FLAG': 'PASSED',
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 102.3564,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 7.9794,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 102.3526,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 102.3945,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 102.3892,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 7.8569,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 102.2780,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 7.8342,
#   'RADIATIVE_TRANSFER_ACCURAY': 0,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 7.8076,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 7.7847,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 8.0161,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 7.7967,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 7.9070,
#   'DARK_FEATURES_PERCENTAGE': 0.0097,
#   'HIGH_PROBA_CLOUDS_PERCENTAGE': 0.0094,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 7.8824,
#   'MEAN_SOLAR_ZENITH_ANGLE': 30.6150,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 7.9377,
#   'MGRS_TILE': '35RNK',
#   'CLOUDY_PIXEL_PERCENTAGE': 0.9371,
#   'GENERAL_QUALITY_FLAG': 'PASSED',
#   'PRODUCT_ID': 'S2A_MSIL2A_20170328T083601_N0204_R064_T35RNK_20170328T084228',
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 7.8451,
#   'SOLAR_IRRADIANCE_B9': 813.0400,
#   'SNOW_ICE_PERCENTAGE': 0,
#   'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 7.8922,
#   'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 7.9664,
#   'SOLAR_IRRADIANCE_B6': 1288.3200,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 102.3872,
#   'SOLAR_IRRADIANCE_B5': 1425.5600,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 102.3157,
#   'SOLAR_IRRADIANCE_B8': 1036.3900,
#   'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 102.2503,
#   'SOLAR_IRRADIANCE_B7': 1163.1900,
#   'SOLAR_IRRADIANCE_B2': 1941.6300,
#   'SOLAR_IRRADIANCE_B1': 1913.5700,
#   'SOLAR_IRRADIANCE_B4': 1512.7900,
#   'SOLAR_IRRADIANCE_B3': 1822.6100,
#   'BARE_SOILS_PERCENTAGE': 95.7134,
#   'system:asset_size': 1396774832,
#   'WATER_PERCENTAGE': 0.0749,
#   'system:index': '20170328T083601_20170328T084228_T35RNK'}}

# %% [markdown]
# # Fetching images
#
# For a leak repair, grab the image before and after it
#
# Note roughly 10% have results for a 1 day temporal bin
# For each point
# - find the nearest image before the repair
# - and the soonest image after repair
# - save a part of each with metadata
#
# Later we can filter, interpolate, and read into numpy arrays

# %%
import dataset
cache_file = 'sqlite:///{}'.format(cache_dir.dirname().joinpath('cache.db'))
db = dataset.connect(cache_file)
cache_table = db.get_table('cached_ids', primary_id='workorderid')

def get_cached_ids():
    return set(row['workorderid'] for row in cache_table.distinct('workorderid'))

def init_cache(workorderid):
    """We will cache downloads in folders like 'id_after'"""
    if workorderid:
        try:
            cache_table.insert(dict(workorderid=workorderid))
        except:
            db.rollback()
        else:
            db.commit()
    return

#Aggiunge il workorderid per il quale ho già l'immagine
img_path = Path('../../data/scraped_satellite_images/'+satellite.replace("/","_")+'/cache/')
for i in os.listdir(img_path):
    init_cache(i.split('_')[0])

# Conta il set di workorderid già scaricati
len(get_cached_ids())
# Out:
# 289

# %%
# # # Cancella dati dalla tabella
#cache_table.delete()

# Conta il set di workorderid che mancano da provare a scaricare
leak_to_scrape = set(leaks.workorderid).difference(set(get_cached_ids()))

len(leak_to_scrape)
#leak_to_scrape
# Out:
# 977

# %% [markdown]
# ### Test the distance need to get your rectangle
#
# Here we need to tweak `fudge_distance_factor` so that we get the image size of our choice. Start with zero and try -1, -0.5, -.25,0,0.25,0.5,0.75. This is to deal with rounding, projecting between CRS's etc. Don't worry the asserts below will yet you know when it's right.
#
# Occasionaly the problem might be that the leak is at the edge of the image, giving a cropped image. Ignore these rare cases.

# %%
distance = resolution_min*(pixel_length/2.00+fudge_distance_factor)

# %%
import time
import traceback
cached_ids = get_cached_ids()


def get_image_for_leak(i, cached_ids=cached_ids):
    leak = leaks.loc[[i]]
    repo_date_ts = arrow.get(leak.reportdate.values[0]).timestamp()
    
    # crappy way or recording that we tried this one
    workorderid = leak.workorderid.values[0]
    if workorderid in cached_ids:
        logger.info('Skipping cached download for leak id %s ',workorderid)
        return
    
    boundary = get_boundary(leak, distance=distance)
    
    # get image before    
    sentinel2_before = (ee.ImageCollection(satellite)
                        .filterBounds(boundary)
                        .filterDate((repo_date_ts-time_before_report)*1000,(repo_date_ts+time_after_report)*1000)
                        .filterMetadata('CLOUDY_PIXEL_PERCENTAGE','less_than',cloudy_percentage)
                        .sort('system:time_start', opt_ascending=False) # first will be latest
                       )
    
    results = sentinel2_before.size().getInfo()
    if results<1:
        logger.info('Error no results for day before %s',workorderid)
        cached_ids = init_cache(str(workorderid)) # so we know there where no results
        return
        
    # get image after
    sentinel2_after = (ee.ImageCollection(satellite)
                       .filterBounds(boundary)
                       .filterDate((repo_date_ts+time_after_repair)*1000,(repo_date_ts+time_after_repair*2)*1000)
                       .filterMetadata('CLOUDY_PIXEL_PERCENTAGE','less_than',cloudy_percentage)
                       .sort('system:time_start', opt_ascending=True) # first will be earliest
                      )
        
    results = sentinel2_after.size().getInfo()
    if results<1:
        logger.info('Error no results for day after, id %s',workorderid)
        cached_ids = init_cache(str(workorderid)) # so we know there where no results
        return
        
    # download as save images    
    logger.info('results for %s', workorderid)
    image = ee.Image(sentinel2_before.first()).clip(boundary)
    name=str(workorderid)+'_before'
    path,files=download_image(
        image, 
        scale=resolution_min, 
        crs=crs_grid, 
        name=name,
        cache_dir=cache_dir
    )
    # also save metadata so we can filter by date
    with open(path.joinpath('metadata.json'), 'w') as fo:
        metadata = dict(
            image=image.getInfo(),
            scale=resolution_min,
            crs=crs_grid,
            name=name,
            distance=distance,
            leak=json.loads(leak.to_json())
        )
        json.dump(metadata, fo)

    image = ee.Image(sentinel2_after.first()).clip(boundary)
    name=str(workorderid)+'_after'
    path,files=download_image(
        image, 
        scale=resolution_min, 
        crs=crs_grid, 
        name=name,
        cache_dir=cache_dir
    )
    with open(path.joinpath('metadata.json'), 'w') as fo:
        metadata = dict(
            image=image.getInfo(),
            scale=resolution_min,
            crs=crs_grid,
            name=name,
            distance=distance,
            leak=json.loads(leak.to_json())
        )
        json.dump(metadata, fo)
    cached_ids = init_cache(str(workorderid)) # so we know there where results
    return

leak_to_scrape = set(leaks.workorderid).difference(set(cached_ids))
for i in tqdm(leak_to_scrape):
    try:
        get_image_for_leak(i)
    except urllib.error.HTTPError as e:
        print(i,e) # "HTTP Error 429: unknown"
        traceback.print_stack()
        if e.code == 429:
            print('sleep for 13s')
            time.sleep(13);
    except ee.ee_exception.EEException as e:
        print(i,e) # "Earth Engine memory capacity exceeded."
        traceback.print_stack()
        ee.Initialize()
    except zipfile.BadZipFile as e:
        print(i,e) # "File is not a zip file"
        traceback.print_stack()
    except Exception as e:
        print(i,e)
        traceback.print_stack()
# Out:
#   0%|          | 0/977 [00:00<?, ?it/s]

# %% [markdown]
# # Load Tiffs to Arrays

# %%
### Variabile per estrarre o meno anche i dati della quota e della pendenza
bands = bands_s2_l2a
dem_bands = False

import shapely
X = []
y = []
t = []
m = []
discarded=[]
for path in tqdm(cache_dir.listdir()):
    files = [file.relpath(path) for file in path.listdir() if file.endswith('.tif')]
    if files:
        # check metadata
        try:
            metadata = json.load(open(path.joinpath('metadata.json')))
        except (FileNotFoundError, ValueError) as e:
            path.move(path.replace(path.basename(),'.deleteme-'+str(uuid.uuid4())))
            if '_after_' in path: # also delete the before path                
                path_after = Path(path.replace('_after_','_before_'))
                if path_after.isdir():
                    path_after.move(path.replace(path.basename(),'.deleteme-'+str(uuid.uuid4())))
            logger.error('Invalid metadata.json, deleted folder %s, please rerun scraping cell to rescrape this image', path)
            continue
        
        # e.g. lets filter it so "before" image are only 1 day before
        if '_before_' in path.basename():
            yy = True
        else:
            yy = False
        
        # work out time gap too
        t1 = arrow.get(metadata['image']['properties']['system:time_end']/1000)
        t0 = arrow.get(metadata['leak']['features'][0]['properties']['reportdate'])
        td=t1-t0
        tt = td.total_seconds()
        
        # load data
        data = tifs2np(path,files,bands=bands)
             
        # check we don't have empty bands 1-13
        empty_bands = np.array([d.sum() for d in data])==0
        
        # lets check we didn't get the edge of an image
        bbox = np.array(metadata['image']['properties']['system:footprint']['coordinates'][0])
        loc = metadata['leak']['features'][0]['geometry']['coordinates']
        minx=bbox[:,0].min()
        maxx=bbox[:,0].max()
        miny=bbox[:,1].min()
        maxy=bbox[:,1].max()
        bbox_shp = shapely.geometry.box(
            minx=minx,
            maxx=maxx,
            miny=miny,
            maxy=maxy
        )
        loc_shp = shapely.geometry.Point(loc[0],loc[1])
        shapely.geometry.GeometryCollection([bbox_shp, loc_shp])
        try:
#             print('QA60', data[bands.index('QA60')].max(), data[bands.index('QA60')].min())
#             print('SCL', data[bands.index('SCL')].max(), data[bands.index('SCL')].min())
            assert loc_shp.intersects(bbox_shp), 'leak location should be inside image'
            assert bbox_shp.centroid.almost_equals(loc_shp, decimal=5), 'leak should be near center of image'
            assert (np.array([d.shape for d in data])==pixel_length).all(), 'image area should be the right amount of pixels'
            assert not empty_bands.all(), 'should not have all bands empty'
            assert sum(np.where(data[bands.index('QA60')]>=1024,1,0).flatten())/len(data[bands.index('QA60')].flatten()) < 0.05, print('image area è troppo nuvolosa QA60. Percentuale ',sum(np.where(data[bands.index('SCL')]>=7,1,0).flatten())/len(data[bands.index('SCL')].flatten()), 'range(', data[bands.index('QA60')].max(), data[bands.index('QA60')].min(),')')
            assert sum(np.where(data[bands.index('SCL')]>=7,1,0).flatten())/len(data[bands.index('SCL')].flatten()) < 0.15, print('image area è troppo nuvolosa SCL. Percentuale ', sum(np.where(data[bands.index('SCL')]>=7,1,0).flatten())/len(data[bands.index('SCL')].flatten()), 'range(', data[bands.index('SCL')].max(), data[bands.index('SCL')].min(),')')
        except Exception as exc:
            print(path, exc)
            discarded.append(path)
        else:
            #riferimenti al file DEM relativo alla perdita
            if dem_bands:
                path_dem = Path(path.replace(satellite.replace("/","_"),'USGS_SRTMGL1_003').replace('after_','').replace('before_','').replace('after2_','') )
                files_dem = [file.relpath(path_dem) for file in path_dem.listdir() if file.endswith('.tif')]
                metadata_dem = json.load(open(path_dem.joinpath('metadata.json')))
                data_dem = tifs2np(path_dem, files_dem, bands=bands_srtm)
                data = np.concatenate((data,data_dem), axis=0)
                if data_dem[0].max() > 2000: 
                    print('quota maggiore di 2000 m', path_dem)
            X.append(data)
            y.append(yy)
            t.append(tt)
            m.append(metadata)

if dem_bands:
    bands = bands_s2_l2a_dem

len(X), len(discarded)
# Out:
#   0%|          | 0/608 [00:00<?, ?it/s]
# C:\Users\TRANFA~1.CAR\AppData\Local\Temp/ipykernel_17724/2233136586.py:63: ShapelyDeprecationWarning: The 'almost_equals()' method is deprecated and will be removed in Shapely 2.0
#   assert bbox_shp.centroid.almost_equals(loc_shp, decimal=5), 'leak should be near center of image'
# image area è troppo nuvolosa SCL. Percentuale  0.4304 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1078256_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.464 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1078256_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2064 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1089867_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3344 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1127705_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2448 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1127705_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1728 range( 8.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1171534_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3952 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1172258_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2544 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1172258_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1696 range( 7.0 3.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1173311_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2304 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1173335_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1824 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1173405_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3232 range( 8.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1405259_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1888 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1461277_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3456 range( 9.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1461277_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.4992 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1502254_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3584 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1502254_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.5328 range( 9.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1507223_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.5408 range( 9.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1507223_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2368 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1508061_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2608 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1508061_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1552 range( 8.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1559839_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.176 range( 8.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1570926_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.192 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1571196_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2352 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1577158_after_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.4944 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1665660_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3088 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1665768_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.3056 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1670278_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1632 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1671195_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1568 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1710326_before_3857_10.0 None
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\1891465_after_3857_10.0 leak should be near center of image
# image area è troppo nuvolosa SCL. Percentuale  0.2256 range( 7.0 2.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2024513_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.2176 range( 7.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2042278_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.1648 range( 7.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2122517_before_3857_10.0 None
# image area è troppo nuvolosa SCL. Percentuale  0.184 range( 9.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2222311_before_3857_10.0 None
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2297385_after_3857_10.0 leak location should be inside image
# image area è troppo nuvolosa SCL. Percentuale  0.4096 range( 10.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2297437_before_3857_10.0 None
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2628068_after_3857_10.0 leak should be near center of image
# image area è troppo nuvolosa QA60. Percentuale  1.0 range( 1024.0 1024.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2656988_after_3857_10.0 None
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2657835_before_3857_10.0 leak should be near center of image
# image area è troppo nuvolosa SCL. Percentuale  0.1952 range( 8.0 4.0 )
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2674832_after_3857_10.0 None
# ../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR/cache\2717906_before_3857_10.0 leak should be near center of image
# (567, 41)

# %%
# record cofig in a json file
metadata = dict(
    notebook_name=notebook_name,
    satellite=satellite,
    time_before_report=time_before_report,
    time_after_report=time_after_report,
    time_after_repair=time_after_repair,
    cloudy_percentage=cloudy_percentage,
    pixel_length=pixel_length,
    resolution_min=resolution_min,
    bands=bands,
    ts=ts,
    crs_grid=crs_grid,
    cache_dir=str(cache_dir),
    temp_dir=str(temp_dir),
    output_dir=str(output_dir),
)
metadata_file = output_dir.joinpath('script_metadata.json')
json.dump(metadata, open(metadata_file,'w'))

bands
# Out:
# ['B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B8',
#  'B8A',
#  'B9',
#  'B11',
#  'B12',
#  'AOT',
#  'WVP',
#  'SCL',
#  'TCI_R',
#  'TCI_G',
#  'TCI_B',
#  'QA10',
#  'QA20',
#  'QA60']

# %%
# img_test = np.transpose((data[1:4,:,:]/10).astype(int),(1,2,0))[:,:,::-1]
# plt.imshow(img_test)

# df_m = pd.Series(X_array[:,bands.index('elevation'),:,:].flatten())
# df_m[df_m<2000].hist(bins=100)

# %%
#### Grafico Bande
X_array = np.array(X)
dim = X_array.shape[0]*X_array.shape[2]*X_array.shape[3]

wonum = np.array([ [m[i]['leak']['features'][0]['properties']['metadata']['wonum']]*X_array.shape[2]*X_array.shape[3] for i in range(len(m)) ]).reshape(dim)
reportdate = np.array([ [m[i]['leak']['features'][0]['properties']['reportdate']]*X_array.shape[2]*X_array.shape[3] for i in range(len(m)) ]).reshape(dim)
month = np.array([ [ arrow.get(m[i]['leak']['features'][0]['properties']['reportdate']).month]*X_array.shape[2]*X_array.shape[3] for i in range(len(m)) ]).reshape(dim)
hour = np.array([ [ arrow.get(m[i]['leak']['features'][0]['properties']['reportdate']).hour]*X_array.shape[2]*X_array.shape[3] for i in range(len(m)) ]).reshape(dim)
B2 = (X_array[:,bands.index('B2')].reshape(dim)/10).astype(int)
B3 = (X_array[:,bands.index('B3')].reshape(dim)/10).astype(int)
B4 = (X_array[:,bands.index('B4')].reshape(dim)/10).astype(int)
TCI_R = X_array[:,bands.index('TCI_R')].reshape(dim)
TCI_G = X_array[:,bands.index('TCI_G')].reshape(dim)
TCI_B = X_array[:,bands.index('TCI_B')].reshape(dim)
B8 = X_array[:,bands.index('B8')].reshape(dim)
B8A = X_array[:,bands.index('B8A')].reshape(dim)
B11 = X_array[:,bands.index('B11')].reshape(dim)
B12 = X_array[:,bands.index('B12')].reshape(dim)
leak = np.array([[y[i]]*X_array.shape[2]*X_array.shape[3] for i in range(len(y))]).reshape(dim)
metadata = np.array([ [m[i]]*X_array.shape[2]*X_array.shape[3] for i in range(len(m)) ]).reshape(dim)

bands_array = np.array((wonum, reportdate, month, hour, B2, B3, B4, B8, B11, B12, leak, metadata),dtype=object).T
data_bands = pd.DataFrame(bands_array, columns = ['wonum','reportdate', 'month', 'hour', 'B','G','R','NIR','SWIR1','SWIR2','leak','metadata'])

data_bands
# Out:
#               wonum                        reportdate month hour    B    G  \
# 0       17ODL199837  2017-03-30T13:08:37.516998+00:00     3   13   16   31
# 1       17ODL199837  2017-03-30T13:08:37.516998+00:00     3   13   16   27
# 2       17ODL199837  2017-03-30T13:08:37.516998+00:00     3   13   14   22
# 3       17ODL199837  2017-03-30T13:08:37.516998+00:00     3   13   14   22
# 4       17ODL199837  2017-03-30T13:08:37.516998+00:00     3   13   18   28
# ...             ...                               ...   ...  ...  ...  ...
# 354370  22ODL162561         2022-02-22T09:34:00+00:00     2    9  152  180
# 354371  22ODL162561         2022-02-22T09:34:00+00:00     2    9  152  180
# 354372  22ODL162561         2022-02-22T09:34:00+00:00     2    9  154  172
# 354373  22ODL162561         2022-02-22T09:34:00+00:00     2    9  194  227
# 354374  22ODL162561         2022-02-22T09:34:00+00:00     2    9  191  234
#
#           R     NIR   SWIR1   SWIR2   leak  \
# 0         3  3068.0  1072.0   422.0  False
# 1         4  2612.0  1072.0   422.0  False
# 2         7  2056.0  1198.0   500.0  False
# 3         7  2056.0  1198.0   500.0  False
# 4        15  2231.0  1198.0   500.0  False
# ...     ...     ...     ...     ...    ...
# 354370  210  2910.0  3258.0  3162.0   True
# 354371  210  2910.0  3258.0  3162.0   True
# 354372  177  2870.0  3258.0  3162.0   True
# 354373  275  3858.0  3652.0  3597.0   True
# 354374  325  4108.0  3652.0  3597.0   True
#
#                                                  metadata
# 0       {'image': {'type': 'Image', 'bands': [{'id': '...
# 1       {'image': {'type': 'Image', 'bands': [{'id': '...
# 2       {'image': {'type': 'Image', 'bands': [{'id': '...
# 3       {'image': {'type': 'Image', 'bands': [{'id': '...
# 4       {'image': {'type': 'Image', 'bands': [{'id': '...
# ...                                                   ...
# 354370  {'image': {'type': 'Image', 'bands': [{'id': '...
# 354371  {'image': {'type': 'Image', 'bands': [{'id': '...
# 354372  {'image': {'type': 'Image', 'bands': [{'id': '...
# 354373  {'image': {'type': 'Image', 'bands': [{'id': '...
# 354374  {'image': {'type': 'Image', 'bands': [{'id': '...
#
# [354375 rows x 12 columns]

# %%
data_detail = []
for b in range(X_array.shape[1]):
    data_detail.append([bands[b],X_array[:,b].min(),X_array[:,b].max(), np.count_nonzero(X_array[:,b])])

data_detail = pd.DataFrame(data_detail, columns=["Banda","Min","Max","Non Zero"])
print(data_detail)
# Out:
#     Banda    Min      Max  Non Zero
# 0      B1    1.0   2775.0    354375
# 1      B2    1.0  18832.0    354375
# 2      B3    1.0  16912.0    354375
# 3      B4    1.0  16360.0    354375
# 4      B5    1.0  12807.0    354375
# 5      B6   23.0  12517.0    354375
# 6      B7   25.0  11025.0    354375
# 7      B8   38.0  16080.0    354375
# 8     B8A  100.0  12205.0    354375
# 9      B9  193.0   6272.0    354375
# 10    B11  104.0  11370.0    354375
# 11    B12   64.0  10919.0    354375
# 12    AOT   58.0    563.0    354375
# 13    WVP   54.0   4049.0    354375
# 14    SCL    2.0     11.0    354375
# 15  TCI_R    0.0    255.0    354152
# 16  TCI_G    0.0    255.0    354269
# 17  TCI_B    0.0    255.0    353732
# 18   QA10    0.0      0.0         0
# 19   QA20    0.0      0.0         0
# 20   QA60    0.0      0.0         0

# %%
plt.figure(figsize = (20,20))

data_bands['NIR'].plot.hist(bins=1000, alpha = 0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plt.figure(figsize = (8,8))

# data_bands['hour'].plot.hist(bins=12, alpha = 0.5)

# sns.scatterplot(data=data_bands, x='G', y='hour' )
# plt.show()
sns.histplot(data=data_bands.loc[data_bands["G"]<30], x='G', hue='hour', stat='density', palette = 'Set2')
plt.show()

# %%
#### Grafico infrarosso
sns.set(rc={'figure.figsize':(20,8)})

# sns.scatterplot(data=data_bands, x="NIR", y="SWIR1", hue="leak")
# plt.show()
# sns.scatterplot(data=data_bands, x="NIR", y="SWIR2", hue="leak")
# plt.show()
print("Curva NIR con perdita")
sns.histplot(data=data_bands[data_bands['leak']==True], x='NIR', hue='month' )
plt.show()
print("Curva NIR senza perdita")
sns.histplot(data=data_bands[data_bands['leak']==False], x='NIR', hue='month' )
plt.show()
# sns.scatterplot(data=data_bands, x="NIR", y="SWIR1", hue="month")
# Out:
# Curva NIR con perdita
# Curva NIR senza perdita

# %%
### Grafico infrarosso - mesi
sns.scatterplot(data=data_bands.loc[data_bands['wonum']==wonum],x="NIR", y="SWIR1", hue="leak")
plt.show()
sns.scatterplot(data=data_bands.loc[data_bands['wonum']==wonum],x="NIR", y="SWIR2", hue="leak")
plt.show()

# %%
import random
wo_id = random.randint(0, len(data_bands))
wonum = data_bands['wonum'].iloc[wo_id]
data = data_bands['reportdate'].iloc[wo_id]
print(wonum, data)

leak_nir = data_bands.loc[data_bands['wonum']==wonum].loc[data_bands['leak']==True]["NIR"]
leak_swir1 = data_bands.loc[data_bands['wonum']==wonum].loc[data_bands['leak']==True]["SWIR1"]
leak_swir2 = data_bands.loc[data_bands['wonum']==wonum].loc[data_bands['leak']==True]["SWIR2"]
noleak_nir = data_bands.loc[data_bands['wonum']==wonum].loc[data_bands['leak']==False]["NIR"]
noleak_swir1 = data_bands.loc[data_bands['wonum']==wonum].loc[data_bands['leak']==False]["SWIR1"]
noleak_swir2 = data_bands.loc[data_bands['wonum']==wonum].loc[data_bands['leak']==False]["SWIR2"]

leak_nir = np.array(leak_nir,dtype='float').reshape(25,25)
leak_nir_norm = (leak_nir-leak_nir.min())/(leak_nir.max()-leak_nir.min())
leak_swir1 = np.array(leak_swir1,dtype='float').reshape(25,25)
leak_swir1_norm = (leak_swir1-leak_swir1.min())/(leak_swir1.max()-leak_swir1.min())
leak_swir2 = np.array(leak_swir2,dtype='float').reshape(25,25)
leak_swir2_norm = (leak_swir2-leak_swir2.min())/(leak_swir2.max()-leak_swir2.min())

noleak_nir = np.array(noleak_nir,dtype='float').reshape(25,25)
noleak_nir_norm = (noleak_nir-noleak_nir.min())/(noleak_nir.max()-noleak_nir.min())
noleak_swir1 = np.array(noleak_swir1,dtype='float').reshape(25,25)
noleak_swir1_norm = (noleak_swir1-noleak_swir1.min())/(noleak_swir1.max()-noleak_swir1.min())
noleak_swir2 = np.array(noleak_swir2,dtype='float').reshape(25,25)
noleak_swir2_norm = (noleak_swir2-noleak_swir2.min())/(noleak_swir2.max()-noleak_swir2.min())
# Out:
# 18ODL386128 2018-10-03T05:49:59.297001+00:00

# %%
### Immagine random
fig, ((nir_leak, nir_noleak), (swir1_leak, swir1_noleak), (swir2_leak, swir2_noleak)) = plt.subplots(3,2)


nir_leak.set_title("NIR Perdita")
nir_leak.imshow(leak_nir_norm)

nir_noleak.set_title("NIR Non Perdita")
nir_noleak.imshow(noleak_nir_norm)

swir1_leak.set_title("SWIR1 Perdita")
swir1_leak.imshow(leak_swir1_norm)

swir1_noleak.set_title("SWIR1 Non Perdita")
swir1_noleak.imshow(noleak_swir1_norm)

swir2_leak.set_title("SWIR1 Perdita")
swir2_leak.imshow(leak_swir2_norm)

swir2_noleak.set_title("SWIR1 Non Perdita")
swir2_noleak.imshow(noleak_swir2_norm)
plt.show()

# %%
# shuffle
from sklearn.utils import shuffle
X,y,m,t = shuffle(X,y,m,t,random_state=1337)

# %%
# save using hdf5 (so keras can easily load it) and json 
import h5py
h5file = output_dir.joinpath('data.h5')
with h5py.File(h5file, 'w') as h5f:
    h5f.create_dataset('X', data=X)
    h5f.create_dataset('y', data=y)
    h5f.create_dataset('t', data=t)

json.dump(m,open(output_dir.joinpath('data_metadata.json'),'w'))

with open(output_dir.joinpath('readme.md'),'w') as fo:
    fo. write("""
Files:
- ee_ee_scraping_earth_engine_sentinel_2-austin_leaks- cached tiff files
- script_metadata.json - information on scraping script
- data.h5 contains X, y, and t.
    - X: tiff files for each band loaded into an array of shape (Leak, Bands, width, length)
    - y: True for before the leak, False for after
    - t: time before leak (can be negative) in seconds
- data_metadata: array of metadata for each leak in X. Each contain info on leak, image, and image search
    
Loading: 
```py
# load
metadatas = json.load(open('data_metadata.json'))
with h5py.File('data.h5','r') as h5f:
    X2 = h5f['X'][:]
    y2 = h5f['y'][:]
    t2 = h5f['t'][:]
y
```
    """)

# %%
# test load
metadatas = json.load(open(output_dir.joinpath('data_metadata.json')))
with h5py.File(output_dir.joinpath('data.h5'),'r') as h5f:
    X2 = h5f['X'][:]
    y2 = h5f['y'][:]
    t2 = h5f['t'][:]
X2.shape, y2, t2, metadatas[0].keys()
# Out:
# ((567, 21, 25, 25),
#  array([ True,  True,  True, False,  True, False,  True,  True,  True,
#         False,  True, False, False, False, False, False, False, False,
#          True, False,  True, False, False,  True,  True,  True, False,
#          True,  True, False, False, False,  True, False, False,  True,
#          True, False,  True,  True,  True,  True, False, False, False,
#         False, False,  True,  True, False, False,  True,  True, False,
#         False,  True,  True,  True, False,  True, False,  True,  True,
#          True, False, False,  True, False,  True,  True,  True, False,
#         False,  True, False, False,  True, False, False, False, False,
#          True,  True,  True, False,  True,  True,  True,  True,  True,
#          True, False, False,  True,  True,  True,  True, False, False,
#         False, False, False,  True, False, False,  True,  True, False,
#          True,  True, False,  True,  True, False, False, False, False,
#          True, False,  True, False, False,  True, False, False,  True,
#         False, False, False, False, False, False,  True, False, False,
#          True, False,  True,  True,  True, False, False, False,  True,
#         False,  True,  True, False,  True, False, False, False,  True,
#         False, False, False, False,  True,  True,  True,  True,  True,
#         False, False,  True,  True, False, False,  True,  True, False,
#         False,  True,  True,  True, False, False,  True,  True, False,
#          True, False,  True, False, False, False,  True, False, False,
#          True,  True,  True, False,  True, False,  True,  True, False,
#         False,  True, False, False, False,  True, False, False, False,
#         False, False, False, False, False, False,  True, False,  True,
#         False, False, False, False, False,  True,  True, False,  True,
#         False,  True,  True, False, False,  True, False,  True, False,
#          True, False, False, False,  True,  True,  True,  True,  True,
#          True,  True, False, False,  True, False, False, False, False,
#         False,  True, False,  True,  True,  True,  True,  True, False,
#          True, False, False,  True,  True,  True,  True,  True,  True,
#         False,  True,  True, False,  True, False, False, False, False,
#          True,  True,  True, False,  True, False, False,  True,  True,
#         False, False,  True, False, False, False, False,  True,  True,
#         False, False,  True,  True,  True, False, False,  True, False,
#         False, False,  True,  True,  True,  True,  True, False,  True,
#          True, False,  True, False,  True,  True,  True, False, False,
#         False,  True, False, False,  True,  True, False, False, False,
#          True, False,  True, False,  True, False, False,  True, False,
#          True,  True, False, False,  True,  True, False,  True,  True,
#          True, False,  True,  True,  True, False, False, False, False,
#          True, False,  True,  True, False,  True, False,  True, False,
#         False,  True,  True,  True,  True,  True, False, False, False,
#         False, False, False, False, False,  True, False,  True,  True,
#         False, False,  True,  True,  True,  True,  True,  True, False,
#         False,  True,  True, False, False,  True, False, False,  True,
#          True,  True,  True,  True, False, False, False,  True, False,
#         False, False,  True,  True,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True, False, False, False,
#          True,  True,  True,  True,  True, False, False,  True, False,
#          True,  True,  True,  True, False,  True, False, False, False,
#         False, False,  True,  True,  True,  True,  True, False, False,
#         False,  True,  True,  True,  True,  True, False,  True, False,
#          True, False, False,  True, False, False,  True,  True,  True,
#         False, False,  True,  True,  True, False,  True, False, False,
#         False,  True, False,  True, False, False,  True,  True, False,
#         False, False, False, False,  True,  True, False, False,  True,
#          True,  True, False,  True, False,  True, False,  True,  True,
#          True, False, False, False, False,  True, False, False, False,
#          True,  True, False,  True,  True, False, False, False, False,
#         False, False,  True,  True,  True, False,  True,  True, False,
#          True,  True,  True, False, False,  True, False,  True, False,
#         False,  True,  True,  True, False, False, False, False, False,
#          True,  True,  True,  True, False,  True,  True, False,  True]),
#  array([-8.3498e+04, -1.5259e+05, -4.1756e+05,  3.8922e+06, -2.5309e+05,
#          3.7221e+06,  7.5224e+04, -1.8627e+05, -3.3027e+05,  5.1145e+06,
#         -4.2107e+05,  3.0444e+06,  3.1221e+06,  2.6064e+06,  4.4216e+06,
#          5.0219e+06,  4.9312e+06,  2.6144e+06, -8.8251e+04,  2.9556e+06,
#         -3.3173e+05,  2.6797e+06,  5.0004e+06,  1.2529e+04,  6.1049e+03,
#         -1.7907e+05,  3.0648e+06,  1.3334e+04, -4.2053e+05,  3.9785e+06,
#          3.2867e+06,  3.1065e+06,  5.5959e+03,  2.5935e+06,  2.6673e+06,
#         -2.7341e+05, -7.9431e+04,  2.9241e+06, -3.4292e+05, -3.3297e+05,
#         -3.4726e+05, -1.6230e+05,  3.2876e+06,  3.6370e+06,  2.6127e+06,
#          2.8643e+06,  2.8498e+06,  6.2502e+04,  2.6812e+03,  2.6750e+06,
#          2.7752e+06, -9.7794e+04, -7.7370e+04,  2.7807e+06,  3.8877e+06,
#         -9.9121e+03, -1.6214e+05, -3.3874e+05,  4.2945e+06,  2.0386e+04,
#          2.6118e+06, -1.6541e+05, -8.1922e+02, -1.7263e+05,  2.9357e+06,
#          2.7426e+06, -8.1676e+04,  3.8840e+06, -4.1599e+05, -1.0156e+05,
#         -2.4200e+05,  3.0347e+06,  3.2016e+06, -1.2136e+03,  4.2188e+06,
#          4.5929e+06, -3.4783e+05,  3.6247e+06,  3.8078e+06,  3.2896e+06,
#          3.8930e+06, -3.6998e+05, -1.7012e+05, -1.0124e+05,  2.6638e+06,
#         -1.8350e+04,  5.7507e+03, -2.4524e+05, -2.5916e+05, -8.1039e+04,
#         -1.7011e+05,  5.0995e+06,  3.0337e+06,  1.6578e+04, -2.4884e+05,
#         -3.3029e+05, -1.7647e+05,  4.1549e+06,  2.9432e+06,  4.1466e+06,
#          3.4697e+06,  4.8593e+06, -1.8942e+05,  3.0415e+06,  2.6029e+06,
#         -1.7210e+05, -2.5669e+05,  3.0282e+06,  1.5008e+03, -1.8960e+05,
#          3.2744e+06, -7.8958e+04, -1.8806e+05,  2.8358e+06,  2.8745e+06,
#          4.7988e+06,  4.0748e+06, -2.4985e+05,  3.7175e+06, -8.2809e+04,
#          4.9375e+06,  2.9498e+06, -3.5688e+05,  3.6508e+06,  2.8643e+06,
#         -1.6110e+05,  2.8575e+06,  2.6052e+06,  3.3693e+06,  3.8955e+06,
#          5.0531e+06,  3.7122e+06, -3.3858e+04,  3.7310e+06,  4.9413e+06,
#          1.0548e+04,  2.6079e+06, -3.7619e+05, -3.6086e+05, -1.6442e+04,
#          2.6802e+06,  2.7514e+06,  3.7259e+06, -2.5375e+05,  3.1886e+06,
#         -1.0040e+05,  3.9400e+03,  2.8614e+06, -2.5650e+05,  4.2232e+06,
#          3.0301e+06,  3.1087e+06, -1.6501e+04,  4.2441e+06,  5.0937e+06,
#          2.6047e+06,  3.0396e+06, -2.0653e+05, -3.5560e+05, -8.3655e+04,
#          8.2549e+04, -2.4257e+05,  3.9062e+06,  4.2362e+06, -1.6057e+05,
#         -1.6177e+05,  5.1093e+06,  3.7272e+06, -3.4800e+05, -1.4954e+05,
#          2.6540e+06,  2.8560e+06, -1.5506e+05, -1.6837e+05,  3.9442e+03,
#          4.2320e+06,  3.8064e+06, -2.4661e+05, -7.4544e+04,  2.5923e+06,
#         -7.6318e+04,  2.9901e+06, -4.1125e+05,  3.0001e+06,  3.5474e+06,
#          2.8658e+06, -2.4257e+05,  3.1209e+06,  3.2971e+06,  7.2844e+04,
#         -3.3732e+05, -1.5650e+05,  3.0422e+06, -1.6213e+05,  2.5959e+06,
#         -2.4485e+05,  7.3885e+04,  2.8629e+06,  3.5499e+06, -3.4064e+05,
#          4.5635e+06,  3.8756e+06,  2.8401e+06,  1.0066e+04,  2.6953e+06,
#          4.5016e+06,  2.6624e+06,  4.9298e+06,  2.8480e+06,  3.0416e+06,
#          2.6882e+06,  2.8584e+06,  5.1139e+06, -1.0706e+05,  3.2873e+06,
#          1.0671e+04,  2.6050e+06,  2.7790e+06,  4.7644e+06,  2.6914e+06,
#          3.8846e+06, -8.7861e+04,  1.8163e+04,  2.9435e+06, -1.2091e+05,
#          4.2384e+06, -7.0675e+04, -2.4407e+05,  2.6797e+06,  4.9956e+06,
#         -3.3568e+05,  2.9446e+06, -7.9204e+04,  3.4302e+06,  1.5739e+04,
#          2.8573e+06,  2.7709e+06,  3.7233e+06, -3.2993e+05, -1.8821e+05,
#         -2.4385e+05, -1.9770e+05, -3.3290e+05, -1.9850e+04, -3.9067e+05,
#          4.1627e+06,  2.7980e+06, -2.4326e+05,  2.6900e+06,  3.5457e+06,
#          3.9531e+06,  4.5002e+06,  4.3951e+06, -1.6656e+05,  2.6019e+06,
#          7.1247e+04, -1.6885e+05,  7.5748e+04, -2.4707e+05, -2.3394e+05,
#          3.3872e+06, -1.8851e+05,  3.4616e+06,  2.8616e+06,  4.1887e+03,
#         -2.9351e+04, -2.4559e+05,  1.5169e+04, -1.6215e+05, -4.2734e+05,
#          3.9826e+06,  1.7744e+04, -1.1533e+04,  3.0354e+06, -1.6711e+05,
#          5.0886e+06,  4.8326e+06,  3.9051e+06,  2.8653e+06, -1.9742e+05,
#         -9.8955e+04, -4.1425e+05,  3.0954e+06, -2.6942e+05,  2.8539e+06,
#          3.1046e+06, -1.6106e+05, -2.5243e+05,  2.7792e+06,  3.0951e+06,
#          8.7939e+03,  2.9430e+06,  3.2943e+06,  2.7810e+06,  3.2064e+06,
#          1.0554e+04,  7.5369e+04,  2.9157e+06,  2.6655e+06, -7.4193e+04,
#         -1.0834e+05, -1.6465e+05,  2.5967e+06,  2.9219e+06,  3.8340e+03,
#          2.6553e+06,  2.7494e+06,  4.3804e+06, -1.6730e+05, -2.3735e+03,
#         -1.6471e+05, -6.9598e+04, -4.1933e+05,  3.1230e+06, -2.4042e+05,
#          2.2427e+04,  3.6172e+06, -4.2622e+05,  2.9477e+06, -2.8370e+05,
#         -1.6555e+05, -2.4691e+05,  4.9286e+06,  3.1099e+06,  4.8521e+06,
#         -3.9170e+05,  2.8340e+06,  5.0881e+06, -1.6284e+05, -1.6395e+05,
#          4.3002e+06,  3.7869e+06,  2.6373e+06, -3.3172e+05,  2.6888e+06,
#         -1.5908e+05,  3.5425e+06, -6.9347e+04,  3.9911e+06,  4.2235e+06,
#         -8.2161e+04,  2.8602e+06, -1.8242e+05,  1.5263e+04,  2.8670e+06,
#          4.8185e+06, -3.3789e+03, -3.3265e+05,  3.1231e+06, -1.7004e+05,
#         -3.2983e+05, -2.5311e+05,  4.0777e+06, -2.4679e+05, -1.9302e+05,
#          9.8200e+03,  2.5971e+06,  5.0175e+06,  5.1204e+06,  2.6073e+06,
#         -4.2762e+05,  4.5064e+06,  8.5872e+04, -1.6260e+05,  3.2989e+06,
#         -1.6325e+05,  3.0435e+06, -1.8787e+05,  3.8735e+06,  3.9435e+06,
#         -6.3611e+04, -2.1451e+05, -1.1257e+05, -1.4793e+04, -1.6930e+05,
#          2.9504e+06,  3.0944e+06,  2.6659e+06,  4.3026e+06,  4.8253e+06,
#          2.5935e+06,  2.8664e+06,  3.0246e+06, -3.3513e+05,  2.8556e+06,
#          7.0052e+03,  8.4215e+04,  2.7821e+06,  4.7630e+06, -2.4317e+05,
#          1.3531e+04, -1.7209e+05, -3.5129e+05, -2.8561e+05, -1.6293e+05,
#          2.6009e+06,  2.7802e+06, -3.4898e+05, -8.6712e+04,  3.0341e+06,
#          3.9578e+06,  6.3281e+04,  4.2582e+06,  4.4032e+06, -1.7576e+05,
#         -1.6591e+05,  1.3245e+04,  7.5950e+04, -4.1705e+05,  2.8689e+06,
#          3.6964e+06,  2.8689e+06, -2.2604e+05,  3.0420e+06,  2.7788e+06,
#          4.5980e+06, -1.6338e+05, -4.2944e+05, -1.2432e+04, -2.8135e+05,
#         -1.5852e+04, -2.6760e+05,  3.7908e+06, -4.1399e+05,  1.3457e+04,
#         -3.5886e+05, -1.2128e+04, -3.2920e+05, -4.1447e+05,  4.7477e+06,
#          2.8709e+06,  2.6651e+06,  1.7504e+04, -1.6867e+05,  4.0821e+04,
#         -1.7995e+05, -8.1947e+04,  3.1209e+06,  2.8604e+06, -1.4520e+04,
#          2.9415e+06, -2.8440e+05, -1.7421e+05, -8.3292e+04, -1.1155e+05,
#          4.4145e+06, -3.2623e+05,  2.8496e+06,  3.0093e+06,  2.8557e+06,
#          2.7710e+06,  2.6992e+06,  6.7196e+04, -2.4478e+05, -1.1282e+05,
#         -1.6363e+05, -1.0996e+04,  2.6036e+06,  2.8359e+06,  3.1171e+06,
#         -8.8979e+04, -4.2716e+05, -1.5307e+05, -2.5376e+05, -9.0298e+04,
#          2.5951e+06, -6.8775e+04,  4.4091e+06, -3.3391e+05,  3.3351e+06,
#          3.6685e+06, -2.7470e+05,  3.6460e+06,  2.6672e+06,  5.5851e+03,
#         -1.5980e+05, -4.1632e+05,  4.6683e+06,  4.1373e+06, -1.8174e+05,
#         -1.6132e+05, -2.4804e+05,  2.6526e+06, -7.3571e+04,  2.6453e+06,
#          2.6817e+06,  2.6834e+06, -3.4375e+05,  3.6161e+06,  3.7380e+03,
#          3.3432e+06,  3.6366e+06,  8.6339e+04, -8.3669e+04,  2.6845e+06,
#          3.2943e+06,  2.7543e+06,  3.3681e+06,  4.6816e+06,  6.8208e+04,
#         -1.5970e+05,  3.7830e+06,  3.8048e+06,  1.5120e+04, -3.3739e+05,
#         -2.7420e+05,  4.4165e+06,  8.0643e+04,  2.6759e+06,  1.5033e+03,
#          3.8176e+06, -3.2938e+05, -2.7207e+05, -4.0193e+05,  3.4717e+06,
#          3.7902e+06,  3.0341e+06,  2.5953e+06, -1.6077e+05,  3.0367e+06,
#          3.3855e+06,  5.1019e+06,  1.9486e+04, -2.4859e+05,  2.7690e+06,
#         -2.3720e+05, -8.4715e+04,  2.7705e+06,  3.2673e+06,  4.0714e+06,
#          2.7483e+06,  2.5947e+06,  3.2769e+06,  6.9318e+04, -8.1321e+04,
#         -3.5389e+03,  3.0968e+06, -3.3037e+05,  6.8708e+04,  3.5185e+06,
#         -1.9988e+05, -1.7771e+04, -8.0757e+04,  2.5964e+06,  2.6519e+06,
#         -8.0774e+04,  2.6890e+06, -3.6533e+05,  2.7773e+06,  2.9544e+06,
#         -1.5699e+05, -1.8892e+05,  4.4580e+03,  4.1312e+06,  2.6921e+06,
#          2.7392e+06,  2.5968e+06,  2.6031e+06, -3.8507e+05, -3.5510e+05,
#         -1.5270e+05, -2.3996e+05,  5.1547e+06,  4.1923e+03, -4.0330e+03,
#          2.8544e+06, -1.5519e+05]),
#  dict_keys(['image', 'scale', 'crs', 'name', 'distance', 'leak']))

# %%
output_dir
# Out:
# Path('../../../ricerca_perdite/data/scraped_satellite_images/COPERNICUS_S2_SR')
